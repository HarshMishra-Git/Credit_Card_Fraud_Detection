# %%
import pandas as pd

# %%
dataset = pd.read_csv("creditcard.csv")
dataset
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
dataset.head() #display top 5 rows of dataset
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
dataset.tail() #display bottom 5 rows of dataset
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
dataset.shape #find the number of rows and columns of dataset
# Out:
# (284807, 31)

# %%
print("Number of Rows",dataset.shape[0])
print("Number of Columns",dataset.shape[1])
# Out:
# Number of Rows 284807
# Number of Columns 31

# %%
dataset.info() #this function tells about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
dataset.isnull().sum() #this will return the any null value in dataset
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# FEATURE SCALING

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
dataset['Amount']=sc.fit_transform(pd.DataFrame(dataset['Amount']))

# %%
dataset.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
dataset = dataset.drop(['Time'],axis=1)

# %%
dataset.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28    Amount  Class
# ...

# %%
dataset.shape
# Out:
# (284807, 30)

# %%
dataset.duplicated().any()
# Out:
# True

# %%
#not handling imbalance
dataset['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
dataset.drop_duplicates(inplace=True)

dataset.duplicated().any()
# Out:
# False

# %%
dataset.shape
# Out:
# (275663, 30)

# %%
284807-275663
# Out:
# 9144

# %%
dataset['Class'].value_counts() #not handling imbalanced
# Out:
# Class
# 0    275190
# 1       473
# Name: count, dtype: int64

# %%
import seaborn as sns

# %%
sns.countplot(dataset['Class'])
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# Store Feature Matrix In X And Response (Target) In Vector y

# %%
X = dataset.drop('Class',axis=1)
y = dataset['Class']

# %% [markdown]
# Splitting The Dataset Into The Training Set And Test Set

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,
                                                 random_state=42)

# %% [markdown]
# # Handling Imbalanced Dataset

# %% [markdown]
# UNDERSAMPLING

# %%
normal = dataset[dataset['Class']==0]
fraud = dataset[dataset['Class']==1]

# %%
normal.shape
# Out:
# (275190, 30)

# %%
fraud.shape
# Out:
# (473, 30)

# %%
normal_sample=normal.sample(n=473)

# %%
normal_sample.shape
# Out:
# (473, 30)

# %%
new_dataset = pd.concat([normal_sample,fraud],ignore_index=True)

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0    473
# 1    473
# Name: count, dtype: int64

# %%
new_dataset.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0  1.869913 -0.573923 -0.413813  1.268083 -0.659919  0.135353 -0.813531
# 1 -0.531922  0.826997  0.573378 -0.719762  1.448803  0.048425  1.556634
# 2 -0.578769  0.084724  0.310429 -0.271064  2.481671  3.792315 -0.333579
# 3  1.269788 -0.703273 -0.227614 -0.580363 -0.837174 -1.027364 -0.100909
# 4 -1.341512 -1.528476 -0.428997 -1.205779  0.284926  2.329388  1.800838
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.330626  1.321840  0.406956  ...  0.248050  0.722122  0.043755 -0.547640
# 1 -0.718455 -0.049469  0.040185  ... -0.306758 -0.502289 -0.223175  0.078975
# 2  1.019941 -0.247736 -0.378019  ... -0.030887 -0.140689 -0.163934  1.063434
# 3 -0.293687 -0.910070  0.689548  ... -0.423734 -0.977523 -0.062207  0.045430
# 4  0.266453 -1.540286 -0.494524  ...  0.221397  0.425444  0.939942 -2.385771
#
#         V25       V26       V27       V28    Amount  Class
# ...

# %%
X = new_dataset.drop('Class',axis=1)
y = new_dataset['Class']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,
                                                 random_state=42)

# %% [markdown]
# # LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression()
log.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred1 = log.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred1)
# Out:
# 0.9421052631578948

# %%
from sklearn.metrics import precision_score,recall_score,f1_score

# %%
precision_score(y_test,y_pred1)
# Out:
# 0.9789473684210527

# %%
recall_score(y_test,y_pred1)
# Out:
# 0.9117647058823529

# %%
f1_score(y_test,y_pred1)
# Out:
# 0.9441624365482234

# %% [markdown]
# # DECISION TREE CLASSIFIER

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred2 = dt.predict(X_test)

# %%
accuracy_score(y_test,y_pred2)
# Out:
# 0.8736842105263158

# %%
precision_score(y_test,y_pred2)
# Out:
# 0.8679245283018868

# %%
recall_score(y_test,y_pred2)
# Out:
# 0.9019607843137255

# %%
f1_score(y_test,y_pred2)
# Out:
# 0.8846153846153846

# %% [markdown]
# # RANDOM FOREST CLASSIFIER

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred3 = rf.predict(X_test)

# %%
accuracy_score(y_test,y_pred3)
# Out:
# 0.9473684210526315

# %%
precision_score(y_test,y_pred3)
# Out:
# 1.0

# %%
recall_score(y_test,y_pred3)
# Out:
# 0.9019607843137255

# %%
f1_score(y_test,y_pred3)
# Out:
# 0.9484536082474228

# %%
final_data = pd.DataFrame({'Models':['LR','DT','RF'],
              "ACC":[accuracy_score(y_test,y_pred1)*100,
                     accuracy_score(y_test,y_pred2)*100,
                     accuracy_score(y_test,y_pred3)*100
                    ]})

# %%
final_data
# Out:
#   Models        ACC
# 0     LR  94.210526
# 1     DT  87.368421
# 2     RF  94.736842

# %%
import matplotlib.pyplot as plt

# %%
show = final_data.plot.bar(x='Models',y='ACC',legend=False,ylabel = 'ACC')

# %% [markdown]
# # OVER SAMPLING

# %%
X = dataset.drop('Class',axis=1)
y = dataset['Class']

# %%
X.shape
# Out:
# (275663, 29)

# %%
y.shape
# Out:
# (275663,)

# %%
from imblearn.over_sampling import SMOTE

# %%
X_res,y_res = SMOTE().fit_resample(X,y)
y_res.value_counts()
# Out:
# Class
# 0    275190
# 1    275190
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_res,y_res,test_size=0.20,
                                                 random_state=42)

# %% [markdown]
# # LOGISCTIC REGRESSION

# %%
log = LogisticRegression()
log.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred1 = log.predict(X_test)

# %%
accuracy_score(y_test,y_pred1)
# Out:
# 0.9450833969257604

# %%
precision_score(y_test,y_pred1)
# Out:
# 0.972823147647377

# %%
recall_score(y_test,y_pred1)
# Out:
# 0.9156773266912713

# %%
f1_score(y_test,y_pred1)
# Out:
# 0.9433856239756496

# %% [markdown]
# # DECISION TREE CLASSIFIER

# %%
dt=DecisionTreeClassifier()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred2 = dt.predict(X_test)

# %%
accuracy_score(y_test,y_pred2)
# Out:
# 0.9982557505723318

# %%
precision_score(y_test,y_pred2)
# Out:
# 0.9976394109422382

# %%
recall_score(y_test,y_pred2)
# Out:
# 0.9988727887569769

# %%
f1_score(y_test,y_pred2)
# Out:
# 0.9982557188800263

# %% [markdown]
# # RANDOM FOREST CLASSIFIER

# %%
rf = RandomForestClassifier()
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred3 = rf.predict(X_test)

# %%
accuracy_score(y_test,y_pred3)
# Out:
# 0.9999273229405138

# %%
precision_score(y_test,y_pred3)
# Out:
# 0.9998545745396376

# %%
recall_score(y_test,y_pred3)
# Out:
# 1.0

# %%
f1_score(y_test,y_pred3)
# Out:
# 0.9999272819822931

# %%
final_data = pd.DataFrame({'Models':['LR','DT','RF'],
              "ACC":[accuracy_score(y_test,y_pred1)*100,
                     accuracy_score(y_test,y_pred2)*100,
                     accuracy_score(y_test,y_pred3)*100
                    ]})

# %%
final_data
# Out:
#   Models        ACC
# 0     LR  94.508340
# 1     DT  99.825575
# 2     RF  99.992732

# %%
show = final_data.plot.bar(x='Models',y='ACC',legend=False,ylabel = 'ACC')

# %% [markdown]
# # SAVE THE MODEL

# %%
rf1 = RandomForestClassifier()
rf1.fit(X_res,y_res)
# Out:
# RandomForestClassifier()

# %%
import joblib

# %%
joblib.dump(rf1,"credit_card_model")
# Out:
# ['credit_card_model']

# %%
model = joblib.load("credit_card_model")

# %%
pred = model.predict([[8878,2.661802175,5.856393215,-7.653616213,6.379741881,-0.060712119,-3.131549732,-3.103569746,1.778491569,-3.831153716,-7.191604246,7.102988588,-9.928699943,-0.067498378,-10.92418687,-1.697913977,-2.379420985,-2.775113897,0.273798971,-1.382187564,0.39909686,0.73477495,-0.435901182,-0.384765904,-0.286015664,1.007933824,0.413195532,0.280284157,0.303936551
]])
# Out:
# C:\Users\harsh\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
if pred == 0:
    print("Normal Transcation")
else:
    print("Fraudulent Transcation")
# Out:
# Normal Transcation

# %%
pred = model.predict([[2.661802175,5.856393215,-7.653616213,6.379741881,-0.060712119,-3.131549732,-3.103569746,1.778491569,-3.831153716,-7.191604246,7.102988588,-9.928699943,-0.067498378,-10.92418687,-1.697913977,-2.379420985,-2.775113897,0.273798971,-1.382187564,0.39909686,0.73477495,-0.435901182,-0.384765904,-0.286015664,1.007933824,0.413195532,0.280284157,0.303936551,1
]])
# Out:
# C:\Users\harsh\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
if pred == 0:
    print("Normal Transcation")
else:
    print("Fraudulent Transcation")
# Out:
# Fraudulent Transcation
